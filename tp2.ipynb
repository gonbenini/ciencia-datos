# %%
import utils # descarga automaticamente los archivos al importarlo
import pandas as pd
from icecream import ic
ic.disable()
# se puede cambiar la funcion `display(var)` por `ic(var)`

# %%
# TP2 E1

data_path = 'ObesityDataSet_raw_and_data_sinthetic.csv'

# a.ii
# utils.mostrar_archivo('ObesityDataSet_raw_and_data_sinthetic.txt')
# utils.mostrar_archivo('ObesityDataSet_raw_and_data_sinthetic.csv')

# a.iii
df = pd.read_csv(data_path)

# a.iv
# display(df.columns.tolist())

# a.v
# display(df.head())
# display(df[0:5])

# a.vi
# display(df.describe())
display(df.describe(include='all')) # esto es para que muestre toda columna, esto va a incluir tambien las cualitativas.

item_b_analizar_columnas = ''' Tipos de datos y que representan
 Age: Cuantitativa discreta - edad
     depende de contra que lo quieras comprar y que grafico hacer
     en su base para mi es discreta pero se puede tomar como continua
     PREGUNTAR
 Gender: BINARIA: cualitativa nominal dicotomica - genero: h,m
     lo calcule usando el `unique` que me dio el describe, como me dio solo dos valores lo asumi asi.
 Height: Cuantitativa continua - altura en metros
 Weight: Cuantitativa continua - peso en kg
 CALC: Cualitativa ordinal - consume alcohol: no, a veces, frecuentemente, siempre
 FAVC: BINARIA: cualitativa nominal dicotomica - consumo frecuente de comidas altamente caloricas: si, no
 FCVC: Cualitativa ordinal - frecuencia de consumo de vegetales: nunca, a veces, siempre
 NCP: Cualitativa ordinal
 SCC: BINARIA: cualitativa nominal dicotomica
 SMOKE: BINARIA: cualitativa nominal dicotomica
 CH2O: Cualitativa ordinal
 family_history_with_overweight: BINARIA: cualitativa nominal dicotomica
 FAF: Cualitativa ordinal
 TUE: Cualitativa ordinal
 CAEC: Cualitativa ordinal
 MTRANS: Cualitativa nominal (se puede justificar como ordinal?)
 NObeyesdad: Cualitativa ordinal
 Falta indice de masa corporal, BMI
'''
# Out:
#                 Age Gender       Height       Weight       CALC  FAVC  \
# count   2111.000000   2111  2111.000000  2111.000000       2111  2111
# unique          NaN      2          NaN          NaN          4     2
# top             NaN   Male          NaN          NaN  Sometimes   yes
# freq            NaN   1068          NaN          NaN       1401  1866
# mean      24.312600    NaN     1.701677    86.586058        NaN   NaN
# std        6.345968    NaN     0.093305    26.191172        NaN   NaN
# min       14.000000    NaN     1.450000    39.000000        NaN   NaN
# 25%       19.947192    NaN     1.630000    65.473343        NaN   NaN
# 50%       22.777890    NaN     1.700499    83.000000        NaN   NaN
# 75%       26.000000    NaN     1.768464   107.430682        NaN   NaN
# max       61.000000    NaN     1.980000   173.000000        NaN   NaN
#
#                FCVC          NCP   SCC SMOKE         CH2O  \
# count   2111.000000  2111.000000  2111  2111  2111.000000
# ...

# %%
#TP2 adicionales

'''
Codificar un cualitativo nominal con numeros es erroneo porque de ahi se puede deducir (erroneamente) un orden donde no lo hay.
Las cualitativas se pueden transformar (mapear con numeros) con el fin de sintetizar o operar o realizar plots pero luego hay que volver guardarlas decodificadas ?

las discretas no se definen exactamente por tener saltos claros de un numero a otro, sino porque estan encerradas en un rango ?
el problemas con las discretas es que cada valor distino pasa a ser una categoria, entonces 

'''

# %%
#E1 TP3
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[52], line 2
#       1 #E1 TP3
# ----> 2 from pandas_profiling import ProfileReport
#
# ModuleNotFoundError: No module named 'pandas_profiling'
